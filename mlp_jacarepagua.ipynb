# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
from sklearn.preprocessing import StandardScaler

from codecarbon import EmissionsTracker
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
df = pd.read_csv('Interpolado_jacarepagua.csv', sep=',', encoding='utf8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68405 entries, 0 to 68404
# Data columns (total 18 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       68405 non-null  float64
#  1   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  68405 non-null  float64
#  2   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        68405 non-null  float64
#  3   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       68405 non-null  float64
#  4   RADIACAO GLOBAL (Kj/m²)                                68405 non-null  float64
#  5   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           68405 non-null  float64
#  6   TEMPERATURA DO PONTO DE ORVALHO (°C)                   68405 non-null  float64
#  7   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)             68405 non-null  float64
#  8   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)             68405 non-null  float64
#  9   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       68405 non-null  float64
#  10  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       68405 non-null  float64
#  11  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               68405 non-null  float64
#  12  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               68405 non-null  float64
#  13  UMIDADE RELATIVA DO AR, HORARIA (%)                    68405 non-null  float64
#  14  VENTO, DIREÇÃO HORARIA (gr) (° (gr))                   68405 non-null  float64
#  15  VENTO, RAJADA MAXIMA (m/s)                             68405 non-null  float64
#  16  VENTO, VELOCIDADE HORARIA (m/s)                        68405 non-null  float64
#  17  datetime                                               68405 non-null  object
# dtypes: float64(17), object(1)
# memory usage: 9.4+ MB

# %%
X_prec = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_prec = df[['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
X_temp = df[[
       'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_temp = df[['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)']]

# %%
X_umid = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_umid = df[['UMIDADE RELATIVA DO AR, HORARIA (%)']]

# %%
def split_train_test(X, y, train_size):
    X_train, X_test = X[:round(X.shape[0]*train_size)], X[round(X.shape[0]*train_size):]
    y_train, y_test = y[:round(y.shape[0]*train_size)], y[round(y.shape[0]*train_size):]

    return X_train, X_test, y_train, y_test

def plot_prediction_over_time(y_test, predictions, timestamps, start_date=None, end_date=None, save=False):
    timestamps = pd.to_datetime(timestamps)

    data = pd.DataFrame({
        'Timestamp': timestamps,
        'Actual': y_test,
        'Predicted': predictions
    })

    if start_date:
        data = data[data['Timestamp'] >= pd.to_datetime(start_date)]
    if end_date:
        data = data[data['Timestamp'] <= pd.to_datetime(end_date)]

    plt.figure(figsize=(12, 6))
    plt.plot(data['Timestamp'], data['Actual'], label='Actual Values', color='blue', linewidth=2)
    plt.plot(data['Timestamp'], data['Predicted'], label='Predicted Values', color='orange', linewidth=2)
    plt.xlabel('Time')
    plt.ylabel('Values')
    plt.title('Actual vs. Predicted Values Over Time')
    plt.legend()
    plt.grid(True)

    
    if save: 
        plt.savefig(save)
        
    plt.show()


def plot_real_vs_predicted(y_test, predictions, save=False):
    plt.figure(figsize=(8, 8))
    plt.scatter(y_test, predictions, alpha=0.7, color='blue')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--', color='red', linewidth=2, label="Ideal Fit")
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title("Real vs Predicted Values")
    plt.legend()
    plt.grid(True)

    if save: 
        plt.savefig(save)
    
    plt.show()

# %% [markdown]
# MLP temperatura

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_temp)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_temp)

# %%
X_temp_train, X_temp_test, y_temp_train, y_temp_test = split_train_test(X_temp, y_temp, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_temp.shape[1], activation='relu', input_shape=(X_temp.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp temperature train",
    output_file='./codecarbon_emissions_mlp_temperatura_jacarepagua.csv',
    log_level = "critical"
)

tracker.start()


model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mean_absolute_error'] 
)

model.summary()

model.fit(X_temp_train, y_temp_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_temp_test, y_temp_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# [codecarbon WARNING @ 18:28:03] Multiple instances of codecarbon are allowed to run at the same time.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 549 (2.14 KB)
#  Trainable params: 549 (2.14 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 382.5674 - mean_absolute_error: 5.9835
# Epoch 2/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.9699 - mean_absolute_error: 2.5286
# Epoch 3/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.9272 - mean_absolute_error: 2.5388
# Epoch 4/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 10.8990 - mean_absolute_error: 2.6570
# Epoch 5/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 11.6139 - mean_absolute_error: 2.7256
# Epoch 6/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 11.3351 - mean_absolute_error: 2.6907
# Epoch 7/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 11.4226 - mean_absolute_error: 2.7030
# Epoch 8/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 10.7429 - mean_absolute_error: 2.6333
# Epoch 9/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 10.2989 - mean_absolute_error: 2.5820
# Epoch 10/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 11.0514 - mean_absolute_error: 2.6443
# Epoch 11/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 10.7821 - mean_absolute_error: 2.6346
# Epoch 12/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 10.4387 - mean_absolute_error: 2.5960
# Epoch 13/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.9120 - mean_absolute_error: 2.5426
# Epoch 14/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 10.2393 - mean_absolute_error: 2.5661
# Epoch 15/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.7930 - mean_absolute_error: 2.5298
# Epoch 16/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 10.0663 - mean_absolute_error: 2.5510
# Epoch 17/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.8737 - mean_absolute_error: 2.5362
# Epoch 18/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.2842 - mean_absolute_error: 2.4685
# Epoch 19/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.7639 - mean_absolute_error: 2.5188
# Epoch 20/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.6693 - mean_absolute_error: 2.5096
# Epoch 21/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.2834 - mean_absolute_error: 2.4680
# Epoch 22/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.3100 - mean_absolute_error: 2.4724
# Epoch 23/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.3334 - mean_absolute_error: 2.4704
# Epoch 24/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.9888 - mean_absolute_error: 2.4312
# Epoch 25/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.0059 - mean_absolute_error: 2.4323
# Epoch 26/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.6550 - mean_absolute_error: 2.3902
# Epoch 27/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.6411 - mean_absolute_error: 2.3897
# Epoch 28/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 8.4853 - mean_absolute_error: 2.3692
# Epoch 29/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.4991 - mean_absolute_error: 2.3744
# Epoch 30/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.5121 - mean_absolute_error: 2.3742
# Epoch 31/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.3000 - mean_absolute_error: 2.3496
# Epoch 32/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 8.3541 - mean_absolute_error: 2.3545
# Epoch 33/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.2976 - mean_absolute_error: 2.3442
# Epoch 34/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 8.2214 - mean_absolute_error: 2.3363
# Epoch 35/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.2619 - mean_absolute_error: 2.3453
# Epoch 36/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.1507 - mean_absolute_error: 2.3291
# Epoch 37/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.1310 - mean_absolute_error: 2.3233
# Epoch 38/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 8.0782 - mean_absolute_error: 2.3171
# Epoch 39/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 8.0173 - mean_absolute_error: 2.3087
# Epoch 40/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 8.0200 - mean_absolute_error: 2.3081
# Epoch 41/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 8.0189 - mean_absolute_error: 2.3084
# Epoch 42/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 8.0153 - mean_absolute_error: 2.3071
# Epoch 43/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 7.9833 - mean_absolute_error: 2.3052
# Epoch 44/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9574 - mean_absolute_error: 2.3003
# Epoch 45/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9773 - mean_absolute_error: 2.3046
# Epoch 46/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9539 - mean_absolute_error: 2.3011
# Epoch 47/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9986 - mean_absolute_error: 2.3070
# Epoch 48/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9480 - mean_absolute_error: 2.3009
# Epoch 49/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9398 - mean_absolute_error: 2.2979
# Epoch 50/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9547 - mean_absolute_error: 2.2986
# Epoch 51/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9674 - mean_absolute_error: 2.3010
# Epoch 52/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9488 - mean_absolute_error: 2.3001
# Epoch 53/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9370 - mean_absolute_error: 2.2979
# Epoch 54/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 7.9341 - mean_absolute_error: 2.2963
# Epoch 55/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9060 - mean_absolute_error: 2.2950
# Epoch 56/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.8893 - mean_absolute_error: 2.2886
# Epoch 57/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9098 - mean_absolute_error: 2.2918
# Epoch 58/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9078 - mean_absolute_error: 2.2931
# Epoch 59/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.9095 - mean_absolute_error: 2.2947
# Epoch 60/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.8796 - mean_absolute_error: 2.2897
# Epoch 61/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.8678 - mean_absolute_error: 2.2872
# Epoch 62/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.8833 - mean_absolute_error: 2.2898
# Epoch 63/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.8861 - mean_absolute_error: 2.2899
# Epoch 64/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.8860 - mean_absolute_error: 2.2909
# Epoch 65/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 7.8385 - mean_absolute_error: 2.2839
# Epoch 66/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 7.8680 - mean_absolute_error: 2.2884
# Epoch 67/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8541 - mean_absolute_error: 2.2856
# Epoch 68/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 7.8757 - mean_absolute_error: 2.2883
# Epoch 69/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8504 - mean_absolute_error: 2.2849
# Epoch 70/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8473 - mean_absolute_error: 2.2845
# Epoch 71/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8533 - mean_absolute_error: 2.2863
# Epoch 72/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8649 - mean_absolute_error: 2.2875
# Epoch 73/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8325 - mean_absolute_error: 2.2829
# Epoch 74/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8396 - mean_absolute_error: 2.2830
# Epoch 75/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8610 - mean_absolute_error: 2.2852
# Epoch 76/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8466 - mean_absolute_error: 2.2842
# Epoch 77/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8619 - mean_absolute_error: 2.2856
# Epoch 78/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8383 - mean_absolute_error: 2.2824
# Epoch 79/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8452 - mean_absolute_error: 2.2846
# Epoch 80/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8441 - mean_absolute_error: 2.2848
# Epoch 81/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8415 - mean_absolute_error: 2.2820
# Epoch 82/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8306 - mean_absolute_error: 2.2817
# Epoch 83/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8259 - mean_absolute_error: 2.2813
# Epoch 84/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.8292 - mean_absolute_error: 2.2808
# Epoch 85/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 7.8256 - mean_absolute_error: 2.2813
# Epoch 86/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.8286 - mean_absolute_error: 2.2812
# Epoch 87/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.8146 - mean_absolute_error: 2.2796
# Epoch 88/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.8146 - mean_absolute_error: 2.2796
# Epoch 89/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.8371 - mean_absolute_error: 2.2820
# Epoch 90/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.7975 - mean_absolute_error: 2.2774
# Epoch 91/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.8153 - mean_absolute_error: 2.2803
# Epoch 92/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.7856 - mean_absolute_error: 2.2766
# Epoch 93/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 7.7991 - mean_absolute_error: 2.2762
# Epoch 94/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.8162 - mean_absolute_error: 2.2804
# Epoch 95/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.8106 - mean_absolute_error: 2.2792
# Epoch 96/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.7942 - mean_absolute_error: 2.2771
# Epoch 97/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.7916 - mean_absolute_error: 2.2765
# Epoch 98/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 7.7906 - mean_absolute_error: 2.2772
# Epoch 99/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.8204 - mean_absolute_error: 2.2792
# Epoch 100/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 7.7853 - mean_absolute_error: 2.2754
# 428/428 - 1s - 2ms/step - loss: 71.8866 - mean_absolute_error: 3.7161
# Loss (MSE): 71.88655853271484
# Mean Absolute Error: 3.7160730361938477
# Root Mean Squared Error (RMSE): 8.478594136572102
# emissions=3.406048359616126e-05

# %%
y_temp_pred_probs = model.predict(X_temp_test, verbose=2)
# Out:
# 428/428 - 0s - 1ms/step

# %%
y_temp_test_flat = y_temp_test.values.flatten()
y_temp_pred_flat = y_temp_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_temp_test_flat, y_temp_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_temp_real_x_pred_jacarepagua.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2025-01-31 23:00:00"

df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_temp_test_flat, y_temp_pred_flat, timestamps_test, start_date, end_date, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_temp_over_time.png')

# %% [markdown]
# MLP precipitação

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_prec)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_prec)

# %%
X_prec_train, X_prec_test, y_prec_train, y_prec_test = split_train_test(X_prec, y_prec, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_prec.shape[1], activation='relu', input_shape=(X_prec.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp PRECIPITATION 100ep final",
    output_file='./codecarbon_emissions_mlp_temperatura_jacarepagua.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_prec_train, y_prec_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_prec_test, y_prec_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 849 (3.32 KB)
#  Trainable params: 849 (3.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 93.0372 - mean_absolute_error: 3.3897
# Epoch 2/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 3.0325 - mean_absolute_error: 0.9511
# Epoch 3/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.7761 - mean_absolute_error: 0.9112
# Epoch 4/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.6985 - mean_absolute_error: 0.9018
# Epoch 5/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.7052 - mean_absolute_error: 0.9241
# Epoch 6/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.5048 - mean_absolute_error: 0.8446
# Epoch 7/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.5773 - mean_absolute_error: 0.8417
# Epoch 8/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.2460 - mean_absolute_error: 0.7537
# Epoch 9/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2.1614 - mean_absolute_error: 0.7292
# Epoch 10/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2.1556 - mean_absolute_error: 0.7129
# Epoch 11/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.9998 - mean_absolute_error: 0.6499
# Epoch 12/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.9629 - mean_absolute_error: 0.6330
# Epoch 13/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.9247 - mean_absolute_error: 0.6170
# Epoch 14/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.9160 - mean_absolute_error: 0.6071
# Epoch 15/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.8966 - mean_absolute_error: 0.5997
# Epoch 16/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.8651 - mean_absolute_error: 0.5732
# Epoch 17/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.8182 - mean_absolute_error: 0.5493
# Epoch 18/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.7992 - mean_absolute_error: 0.5324
# Epoch 19/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.8075 - mean_absolute_error: 0.5316
# Epoch 20/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.7421 - mean_absolute_error: 0.4848
# Epoch 21/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.7289 - mean_absolute_error: 0.4645
# Epoch 22/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6639 - mean_absolute_error: 0.4058
# Epoch 23/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.6091 - mean_absolute_error: 0.3457
# Epoch 24/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5884 - mean_absolute_error: 0.3258
# Epoch 25/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6110 - mean_absolute_error: 0.3173
# Epoch 26/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6456 - mean_absolute_error: 0.3119
# Epoch 27/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6658 - mean_absolute_error: 0.3316
# Epoch 28/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.6358 - mean_absolute_error: 0.3278
# Epoch 29/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6219 - mean_absolute_error: 0.3249
# Epoch 30/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5651 - mean_absolute_error: 0.3147
# Epoch 31/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5447 - mean_absolute_error: 0.3160
# Epoch 32/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5865 - mean_absolute_error: 0.3168
# Epoch 33/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5885 - mean_absolute_error: 0.3164
# Epoch 34/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6003 - mean_absolute_error: 0.3268
# Epoch 35/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5471 - mean_absolute_error: 0.3143
# Epoch 36/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5575 - mean_absolute_error: 0.3147
# Epoch 37/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5346 - mean_absolute_error: 0.3083
# Epoch 38/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5452 - mean_absolute_error: 0.3104
# Epoch 39/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5861 - mean_absolute_error: 0.3084
# Epoch 40/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5619 - mean_absolute_error: 0.3046
# Epoch 41/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6409 - mean_absolute_error: 0.3071
# Epoch 42/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6533 - mean_absolute_error: 0.3043
# Epoch 43/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6534 - mean_absolute_error: 0.3205
# Epoch 44/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6537 - mean_absolute_error: 0.3169
# Epoch 45/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 1.6539 - mean_absolute_error: 0.3170
# Epoch 46/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6501 - mean_absolute_error: 0.3184
# Epoch 47/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.6511 - mean_absolute_error: 0.3233
# Epoch 48/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6514 - mean_absolute_error: 0.3189
# Epoch 49/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6539 - mean_absolute_error: 0.3151
# Epoch 50/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6492 - mean_absolute_error: 0.3108
# Epoch 51/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6504 - mean_absolute_error: 0.3272
# Epoch 52/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6516 - mean_absolute_error: 0.3144
# Epoch 53/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6437 - mean_absolute_error: 0.3171
# Epoch 54/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6492 - mean_absolute_error: 0.3205
# Epoch 55/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6470 - mean_absolute_error: 0.3296
# Epoch 56/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6626 - mean_absolute_error: 0.3171
# Epoch 57/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6578 - mean_absolute_error: 0.3087
# Epoch 58/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6579 - mean_absolute_error: 0.3062
# Epoch 59/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6473 - mean_absolute_error: 0.3066
# Epoch 60/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6448 - mean_absolute_error: 0.3204
# Epoch 61/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6424 - mean_absolute_error: 0.3193
# Epoch 62/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6441 - mean_absolute_error: 0.3229
# Epoch 63/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6522 - mean_absolute_error: 0.3164
# Epoch 64/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6458 - mean_absolute_error: 0.3068
# Epoch 65/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6433 - mean_absolute_error: 0.3232
# Epoch 66/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6485 - mean_absolute_error: 0.3175
# Epoch 67/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6415 - mean_absolute_error: 0.3248
# Epoch 68/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6445 - mean_absolute_error: 0.3291
# Epoch 69/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6460 - mean_absolute_error: 0.3308
# Epoch 70/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6460 - mean_absolute_error: 0.3116
# Epoch 71/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6442 - mean_absolute_error: 0.3171
# Epoch 72/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.6445 - mean_absolute_error: 0.3162
# Epoch 73/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6422 - mean_absolute_error: 0.3250
# Epoch 74/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6439 - mean_absolute_error: 0.3245
# Epoch 75/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6428 - mean_absolute_error: 0.3317
# Epoch 76/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6463 - mean_absolute_error: 0.3247
# Epoch 77/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6525 - mean_absolute_error: 0.3167
# Epoch 78/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6445 - mean_absolute_error: 0.3109
# Epoch 79/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6461 - mean_absolute_error: 0.3156
# Epoch 80/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6409 - mean_absolute_error: 0.3250
# Epoch 81/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.6410 - mean_absolute_error: 0.3273
# Epoch 82/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6426 - mean_absolute_error: 0.3286
# Epoch 83/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6412 - mean_absolute_error: 0.3214
# Epoch 84/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6428 - mean_absolute_error: 0.3193
# Epoch 85/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6427 - mean_absolute_error: 0.3211
# Epoch 86/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6426 - mean_absolute_error: 0.3236
# Epoch 87/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6460 - mean_absolute_error: 0.3282
# Epoch 88/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6458 - mean_absolute_error: 0.3238
# Epoch 89/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6433 - mean_absolute_error: 0.3297
# Epoch 90/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6429 - mean_absolute_error: 0.3255
# Epoch 91/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.6464 - mean_absolute_error: 0.3140
# Epoch 92/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6402 - mean_absolute_error: 0.3207
# Epoch 93/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6411 - mean_absolute_error: 0.3265
# Epoch 94/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6413 - mean_absolute_error: 0.3244
# Epoch 95/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6423 - mean_absolute_error: 0.3191
# Epoch 96/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6433 - mean_absolute_error: 0.3178
# Epoch 97/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6412 - mean_absolute_error: 0.3193
# Epoch 98/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6470 - mean_absolute_error: 0.3109
# Epoch 99/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6522 - mean_absolute_error: 0.3113
# Epoch 100/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6475 - mean_absolute_error: 0.3118
# 428/428 - 1s - 2ms/step - loss: 43.8868 - mean_absolute_error: 0.8566
# Loss (MSE): 43.88676071166992
# Mean Absolute Error: 0.8565717339515686
# Root Mean Squared Error (RMSE): 6.624708349178092
# emissions=2.5666199786823432e-05

# %%
rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 6.624708349178092

# %%
y_prec_pred_probs = model.predict(X_prec_test, verbose=2)
# Out:
# 428/428 - 0s - 655us/step

# %%
y_prec_test_flat = y_prec_test.values.flatten()
y_prec_pred_flat = y_prec_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_prec_test_flat, y_prec_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_prec_real_x_pred_jacarepagua.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2024-01-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_prec_test_flat, y_prec_pred_flat, timestamps_test, start_date, end_date,  save='./images/models/mlp_prec_over_time.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 6
#       2 end_date = "2024-01-31 23:00:00"
#       4 timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]
# ----> 6 plot_prediction_over_time(y_prec_test_flat, y_prec_pred_flat, timestamps_test, start_date, end_date,  save='./images/models/mlp_prec_over_time.png')
#
# Cell In[9], line 32, in plot_prediction_over_time(y_test, predictions, timestamps, start_date, end_date, save)
#      28 plt.grid(True)
#      31 if save:
# ---> 32     plt.savefig(save)
#      34 plt.show()
#
# File c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py:2576, in Image.save(self, fp, format, **params)
#    2574         fp = builtins.open(filename, "r+b")
#    2575     else:
# -> 2576         fp = builtins.open(filename, "w+b")
#    2577 else:
#    2578     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/models/mlp_prec_over_time.png'

# %% [markdown]
# MLP umidade

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_umid)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_umid)

# %%
X_umid_train, X_umid_test, y_umid_train, y_umid_test = split_train_test(X_umid, y_umid, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_umid.shape[1], activation='relu', input_shape=(X_umid.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp PRECIPITATION 100ep final",
    output_file='./codecarbon_emissions_mlp_temperatura_jacarepagua.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_umid_train, y_umid_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_umid_test, y_umid_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 13)             │           182 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 663 (2.59 KB)
#  Trainable params: 663 (2.59 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 3670.1409 - mean_absolute_error: 14.5379
# Epoch 2/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 87.1457 - mean_absolute_error: 6.3542
# Epoch 3/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 75.2858 - mean_absolute_error: 5.9292
# Epoch 4/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 54.7752 - mean_absolute_error: 4.9191
# Epoch 5/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 35.3132 - mean_absolute_error: 3.7010
# Epoch 6/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 28.3160 - mean_absolute_error: 3.1192
# Epoch 7/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 26.9143 - mean_absolute_error: 2.9420
# Epoch 8/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 25.4205 - mean_absolute_error: 2.8804
# Epoch 9/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 23.9841 - mean_absolute_error: 2.7322
# Epoch 10/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 23.3883 - mean_absolute_error: 2.6292
# Epoch 11/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 22.6167 - mean_absolute_error: 2.5538
# Epoch 12/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 22.6712 - mean_absolute_error: 2.6241
# Epoch 13/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 22.0509 - mean_absolute_error: 2.5650
# Epoch 14/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 22.8728 - mean_absolute_error: 2.6449
# Epoch 15/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 21.3845 - mean_absolute_error: 2.4156
# Epoch 16/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 21.1183 - mean_absolute_error: 2.4464
# Epoch 17/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 22.2426 - mean_absolute_error: 2.5322
# Epoch 18/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 21.0744 - mean_absolute_error: 2.3997
# Epoch 19/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 21.4930 - mean_absolute_error: 2.4888
# Epoch 20/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 20.3316 - mean_absolute_error: 2.3670
# Epoch 21/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 19.8663 - mean_absolute_error: 2.3233
# Epoch 22/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 19.8423 - mean_absolute_error: 2.3039
# Epoch 23/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 19.4947 - mean_absolute_error: 2.2774
# Epoch 24/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 19.5225 - mean_absolute_error: 2.2494
# Epoch 25/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 19.3571 - mean_absolute_error: 2.2883
# Epoch 26/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 18.2477 - mean_absolute_error: 2.1408
# Epoch 27/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 18.6555 - mean_absolute_error: 2.2181
# Epoch 28/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 18.3562 - mean_absolute_error: 2.1411
# Epoch 29/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 18.3647 - mean_absolute_error: 2.1463
# Epoch 30/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 18.0251 - mean_absolute_error: 2.1288
# Epoch 31/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 17.8696 - mean_absolute_error: 2.0791
# Epoch 32/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 18.2020 - mean_absolute_error: 2.1232
# Epoch 33/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 17.8306 - mean_absolute_error: 2.0985
# Epoch 34/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 17.5645 - mean_absolute_error: 2.0816
# Epoch 35/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 17.1876 - mean_absolute_error: 1.9914
# Epoch 36/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 17.4359 - mean_absolute_error: 2.0523
# Epoch 37/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 16.9849 - mean_absolute_error: 1.9784
# Epoch 38/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 16.9748 - mean_absolute_error: 1.9856
# Epoch 39/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 16.8823 - mean_absolute_error: 1.9738
# Epoch 40/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 16.4100 - mean_absolute_error: 1.8994
# Epoch 41/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 16.6661 - mean_absolute_error: 1.9395
# Epoch 42/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 16.1504 - mean_absolute_error: 1.8370
# Epoch 43/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 16.0457 - mean_absolute_error: 1.8254
# Epoch 44/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.7725 - mean_absolute_error: 1.8251
# Epoch 45/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.9674 - mean_absolute_error: 1.8735
# Epoch 46/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.6050 - mean_absolute_error: 1.7963
# Epoch 47/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.5973 - mean_absolute_error: 1.7786
# Epoch 48/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.7376 - mean_absolute_error: 1.8035
# Epoch 49/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.7255 - mean_absolute_error: 1.8297
# Epoch 50/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.3083 - mean_absolute_error: 1.7522
# Epoch 51/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.2568 - mean_absolute_error: 1.7279
# Epoch 52/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.3656 - mean_absolute_error: 1.7731
# Epoch 53/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.3657 - mean_absolute_error: 1.7653
# Epoch 54/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.1069 - mean_absolute_error: 1.7396
# Epoch 55/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.0163 - mean_absolute_error: 1.7014
# Epoch 56/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.8586 - mean_absolute_error: 1.6902
# Epoch 57/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.1944 - mean_absolute_error: 1.7611
# Epoch 58/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.7749 - mean_absolute_error: 1.6811
# Epoch 59/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.5906 - mean_absolute_error: 1.6740
# Epoch 60/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 15.0556 - mean_absolute_error: 1.6939
# Epoch 61/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.6721 - mean_absolute_error: 1.6432
# Epoch 62/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.9748 - mean_absolute_error: 1.7035
# Epoch 63/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.8567 - mean_absolute_error: 1.6666
# Epoch 64/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.5640 - mean_absolute_error: 1.6414
# Epoch 65/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.5593 - mean_absolute_error: 1.6446
# Epoch 66/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.4719 - mean_absolute_error: 1.6476
# Epoch 67/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.6536 - mean_absolute_error: 1.6138
# Epoch 68/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.2734 - mean_absolute_error: 1.5931
# Epoch 69/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.2350 - mean_absolute_error: 1.6031
# Epoch 70/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.0998 - mean_absolute_error: 1.5765
# Epoch 71/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.1882 - mean_absolute_error: 1.5741
# Epoch 72/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 14.2857 - mean_absolute_error: 1.5766
# Epoch 73/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.9533 - mean_absolute_error: 1.5455
# Epoch 74/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.8136 - mean_absolute_error: 1.5210
# Epoch 75/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.9930 - mean_absolute_error: 1.5503
# Epoch 76/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.6636 - mean_absolute_error: 1.4938
# Epoch 77/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.7608 - mean_absolute_error: 1.5334
# Epoch 78/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.6821 - mean_absolute_error: 1.4980
# Epoch 79/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.7574 - mean_absolute_error: 1.4879
# Epoch 80/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.6022 - mean_absolute_error: 1.4646
# Epoch 81/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.8764 - mean_absolute_error: 1.5488
# Epoch 82/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.7337 - mean_absolute_error: 1.5308
# Epoch 83/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.5288 - mean_absolute_error: 1.4875
# Epoch 84/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.4671 - mean_absolute_error: 1.4604
# Epoch 85/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.8201 - mean_absolute_error: 1.4950
# Epoch 86/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.2950 - mean_absolute_error: 1.4184
# Epoch 87/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.3613 - mean_absolute_error: 1.4331
# Epoch 88/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.1573 - mean_absolute_error: 1.4160
# Epoch 89/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.1901 - mean_absolute_error: 1.4266
# Epoch 90/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.5658 - mean_absolute_error: 1.4847
# Epoch 91/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.1710 - mean_absolute_error: 1.4566
# Epoch 92/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.2254 - mean_absolute_error: 1.4418
# Epoch 93/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.3059 - mean_absolute_error: 1.4430
# Epoch 94/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.0889 - mean_absolute_error: 1.4005
# Epoch 95/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.2727 - mean_absolute_error: 1.4628
# Epoch 96/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.2961 - mean_absolute_error: 1.4160
# Epoch 97/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.1987 - mean_absolute_error: 1.4196
# Epoch 98/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.2871 - mean_absolute_error: 1.4920
# Epoch 99/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.0182 - mean_absolute_error: 1.4171
# Epoch 100/100
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13.1988 - mean_absolute_error: 1.3843
# 428/428 - 1s - 1ms/step - loss: 254.4168 - mean_absolute_error: 3.0938
# Loss (MSE): 254.4167938232422
# Mean Absolute Error: 3.093808650970459
# Root Mean Squared Error (RMSE): 15.950448075939503
# emissions=2.3062170226167252e-05

# %%
rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 15.950448075939503

# %%
y_umid_pred_probs = model.predict(X_umid_test, verbose=2)
# Out:
# 428/428 - 0s - 712us/step

# %%
y_umid_test_flat = y_umid_test.values.flatten()
y_umid_pred_flat = y_umid_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_umid_test_flat, y_umid_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_umid_real_x_pred_jacarepagua.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2025-01-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_umid_test_flat, y_umid_pred_flat, timestamps_test, start_date, end_date,  save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_umid_real_x_pred_jacarepagua_2024-2025.png')
