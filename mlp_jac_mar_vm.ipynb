# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
from sklearn.preprocessing import StandardScaler

from codecarbon import EmissionsTracker
import shap
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
arquivos = ['Interpolado_Marambaia.csv', 'Interpolado_VilaMilitar.csv', 'Interpolado_jacarepagua.csv']
dfs = [pd.read_csv(a, sep=',', encoding='utf8') for a in arquivos]
df = pd.concat(dfs, ignore_index=True)
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
df = df.sort_values(['datetime'], ignore_index=True)
df
# Out:
#         PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0                                    0.0
# 1                                    0.0
# 2                                    3.6
# 3                                    0.0
# 4                                    0.0
# ...                                  ...
# 414824                               0.0
# 414825                               0.0
# 414826                               0.0
# 414827                               0.0
# 414828                               0.0
#
#         PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                             1021.400000
# 1                                             1021.900000
# 2                                             1021.700000
# 3                                             1020.900000
# 4                                             1020.300000
# ...                                                   ...
# 414824                                        1017.800000
# 414825                                        1018.200000
# 414826                                        1019.088889
# 414827                                        1019.733333
# 414828                                        1018.600000
#
#         PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           1021.400000
# 1                                           1022.000000
# 2                                           1022.500000
# 3                                           1021.700000
# 4                                           1020.800000
# ...                                                 ...
# 414824                                      1017.800000
# 414825                                      1018.200000
# 414826                                      1019.088889
# 414827                                      1019.733333
# 414828                                      1018.600000
#
#         PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                            1021.100000
# 1                                            1021.400000
# 2                                            1021.700000
# 3                                            1020.900000
# 4                                            1020.300000
# ...                                                  ...
# 414824                                       1017.400000
# 414825                                       1017.700000
# 414826                                       1018.533333
# 414827                                       1019.000000
# 414828                                       1018.100000
#
#         RADIACAO GLOBAL (Kj/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                           0.0                                     18.200000
# 1                           0.0                                     18.500000
# 2                           0.0                                     17.800000
# 3                           0.0                                     17.400000
# 4                           0.0                                     17.200000
# ...                         ...                                           ...
# 414824                      3.7                                     20.700000
# 414825                      0.0                                     21.400000
# 414826                      0.0                                     20.009091
# 414827                      0.0                                     19.254545
# 414828                      0.0                                     21.400000
#
#         TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                  15.700000
# 1                                  16.200000
# 2                                  15.900000
# 3                                  15.700000
# 4                                  15.600000
# ...                                      ...
# 414824                             17.900000
# 414825                             17.900000
# 414826                             18.066667
# 414827                             18.300000
# 414828                             17.800000
#
#         TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                        18.200000
# 1                                        18.600000
# 2                                        18.500000
# 3                                        17.800000
# 4                                        17.400000
# ...                                            ...
# 414824                                   20.800000
# 414825                                   21.400000
# 414826                                   21.009091
# 414827                                   20.754545
# 414828                                   21.400000
#
#         TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                             18.0
# 1                                             18.2
# 2                                             17.6
# 3                                             17.4
# 4                                             17.2
# ...                                            ...
# 414824                                        20.1
# 414825                                        20.7
# 414826                                        20.2
# 414827                                        19.7
# 414828                                        21.3
#
#         TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                              15.800000
# 1                                              16.300000
# 2                                              16.400000
# 3                                              15.900000
# 4                                              15.800000
# ...                                                  ...
# 414824                                         17.900000
# 414825                                         18.000000
# 414826                                         18.585714
# 414827                                         18.614286
# 414828                                         17.900000
#
#         TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                                  15.40
# 1                                                  15.70
# 2                                                  15.40
# 3                                                  15.70
# 4                                                  15.60
# ...                                                  ...
# 414824                                             17.50
# 414825                                             17.90
# 414826                                             17.35
# 414827                                             16.80
# 414828                                             17.80
#
#         UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      86.000000
# 1                                      87.000000
# 2                                      89.000000
# 3                                      90.000000
# 4                                      91.000000
# ...                                          ...
# 414824                                 85.000000
# 414825                                 84.000000
# 414826                                 85.857143
# 414827                                 86.142857
# 414828                                 81.000000
#
#         UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                           85.0
# 1                                           85.0
# 2                                           86.0
# 3                                           89.0
# 4                                           90.0
# ...                                          ...
# 414824                                      82.0
# 414825                                      80.0
# 414826                                      78.0
# 414827                                      70.0
# 414828                                      80.0
#
#         UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                      86.0
# 1                                      87.0
# 2                                      89.0
# 3                                      90.0
# 4                                      91.0
# ...                                     ...
# 414824                                 84.0
# 414825                                 81.0
# 414826                                 86.0
# 414827                                 89.0
# 414828                                 80.0
#
#         VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                       28.0                         3.8
# 1                                      348.0                         5.9
# 2                                       17.0                         6.1
# 3                                       29.0                         3.0
# 4                                        2.0                         3.9
# ...                                      ...                         ...
# 414824                                 256.0                         3.5
# 414825                                 237.0                         6.2
# 414826                                  47.0                         7.6
# 414827                                  81.0                        10.6
# 414828                                 210.0                         4.5
#
#         VENTO, VELOCIDADE HORARIA (m/s)            datetime
# 0                              2.000000 2002-11-08 00:00:00
# 1                              2.500000 2002-11-08 01:00:00
# 2                              2.500000 2002-11-08 02:00:00
# 3                              1.800000 2002-11-08 03:00:00
# 4                              2.400000 2002-11-08 04:00:00
# ...                                 ...                 ...
# 414824                         0.800000 2025-05-31 21:00:00
# 414825                         1.600000 2025-05-31 22:00:00
# 414826                         2.376190 2025-05-31 22:00:00
# 414827                         6.257143 2025-05-31 23:00:00
# 414828                         0.800000 2025-05-31 23:00:00
#
# [414829 rows x 18 columns]

# %%
X_prec = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_prec = df[['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
X_temp = df[[
       'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_temp = df[['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)']]

# %%
X_umid = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_umid = df[['UMIDADE RELATIVA DO AR, HORARIA (%)']]

# %%
def split_train_test(X, y, train_size):
    X_train, X_test = X[:round(X.shape[0]*train_size)], X[round(X.shape[0]*train_size):]
    y_train, y_test = y[:round(y.shape[0]*train_size)], y[round(y.shape[0]*train_size):]

    return X_train, X_test, y_train, y_test

def plot_prediction_over_time(y_test, predictions, timestamps, start_date=None, end_date=None, save=False):
    timestamps = pd.to_datetime(timestamps)

    data = pd.DataFrame({
        'Timestamp': timestamps,
        'Actual': y_test,
        'Predicted': predictions
    })

    if start_date:
        data = data[data['Timestamp'] >= pd.to_datetime(start_date)]
    if end_date:
        data = data[data['Timestamp'] <= pd.to_datetime(end_date)]

    plt.figure(figsize=(12, 6))
    plt.plot(data['Timestamp'], data['Actual'], label='Actual Values', color='blue', linewidth=2)
    plt.plot(data['Timestamp'], data['Predicted'], label='Predicted Values', color='orange', linewidth=2)
    plt.xlabel('Time')
    plt.ylabel('Values')
    plt.title('Actual vs. Predicted Values Over Time')
    plt.legend()
    plt.grid(True)

    
    if save: 
        plt.savefig(save)
        
    plt.show()


def plot_real_vs_predicted(y_test, predictions, save=False):
    plt.figure(figsize=(8, 8))
    plt.scatter(y_test, predictions, alpha=0.7, color='blue')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--', color='red', linewidth=2, label="Ideal Fit")
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title("Real vs Predicted Values")
    plt.legend()
    plt.grid(True)

    if save: 
        plt.savefig(save)
    
    plt.show()

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_temp)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_temp)

# %%
X_temp_train, X_temp_test, y_temp_train, y_temp_test = split_train_test(X_temp, y_temp, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_temp.shape[1], activation='relu', input_shape=(X_temp.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp temperature train",
    output_file='./codecarbon_emissions_mlp_temperatura_jac_mar_vm.csv',
    log_level = "critical"
)

tracker.start()


model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mean_absolute_error'] 
)

model.summary()

model.fit(X_temp_train, y_temp_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_temp_test, y_temp_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# [codecarbon WARNING @ 23:17:24] Multiple instances of codecarbon are allowed to run at the same time.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 549 (2.14 KB)
#  Trainable params: 549 (2.14 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 1ms/step - loss: 352.8624 - mean_absolute_error: 3.5717
# Epoch 2/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 98.1870 - mean_absolute_error: 2.8165
# Epoch 3/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 13.1298 - mean_absolute_error: 2.7067
# Epoch 4/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 11.3056 - mean_absolute_error: 2.6290
# Epoch 5/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 10.6687 - mean_absolute_error: 2.5766
# Epoch 6/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 10.1898 - mean_absolute_error: 2.5298
# Epoch 7/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 9.7055 - mean_absolute_error: 2.4858
# Epoch 8/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 9.5136 - mean_absolute_error: 2.4677
# Epoch 9/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 9.4503 - mean_absolute_error: 2.4622
# Epoch 10/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 9.3305 - mean_absolute_error: 2.4517
# Epoch 11/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 9.2865 - mean_absolute_error: 2.4448
# Epoch 12/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 9.1772 - mean_absolute_error: 2.4383
# Epoch 13/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 9.2001 - mean_absolute_error: 2.4355
# Epoch 14/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 9.1247 - mean_absolute_error: 2.4303
# Epoch 15/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 9.2200 - mean_absolute_error: 2.4295
# Epoch 16/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 9.0607 - mean_absolute_error: 2.4245
# Epoch 17/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 9.0905 - mean_absolute_error: 2.4231
# Epoch 18/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 9.0157 - mean_absolute_error: 2.4208
# Epoch 19/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 9.0122 - mean_absolute_error: 2.4184
# Epoch 20/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.9844 - mean_absolute_error: 2.4164
# Epoch 21/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 8.9915 - mean_absolute_error: 2.4159
# Epoch 22/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.9579 - mean_absolute_error: 2.4129
# Epoch 23/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 9.1188 - mean_absolute_error: 2.4142
# Epoch 24/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 8.9080 - mean_absolute_error: 2.4067
# Epoch 25/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 8.8819 - mean_absolute_error: 2.4041
# Epoch 26/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.9000 - mean_absolute_error: 2.4047
# Epoch 27/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 1ms/step - loss: 8.8351 - mean_absolute_error: 2.3989
# Epoch 28/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.8483 - mean_absolute_error: 2.3990
# Epoch 29/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.8135 - mean_absolute_error: 2.3956
# Epoch 30/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.7836 - mean_absolute_error: 2.3919
# Epoch 31/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 8.7626 - mean_absolute_error: 2.3889
# Epoch 32/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.7506 - mean_absolute_error: 2.3881
# Epoch 33/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 26s 2ms/step - loss: 8.8150 - mean_absolute_error: 2.3907
# Epoch 34/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.7887 - mean_absolute_error: 2.3898
# Epoch 35/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.7655 - mean_absolute_error: 2.3883
# Epoch 36/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.7155 - mean_absolute_error: 2.3834
# Epoch 37/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.7188 - mean_absolute_error: 2.3824
# Epoch 38/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 8.6766 - mean_absolute_error: 2.3786
# Epoch 39/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.6644 - mean_absolute_error: 2.3762
# Epoch 40/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.6634 - mean_absolute_error: 2.3751
# Epoch 41/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.6473 - mean_absolute_error: 2.3735
# Epoch 42/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.6427 - mean_absolute_error: 2.3721
# Epoch 43/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.6273 - mean_absolute_error: 2.3696
# Epoch 44/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.6254 - mean_absolute_error: 2.3706
# Epoch 45/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.5982 - mean_absolute_error: 2.3668
# Epoch 46/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.5898 - mean_absolute_error: 2.3655
# Epoch 47/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.5896 - mean_absolute_error: 2.3645
# Epoch 48/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.5751 - mean_absolute_error: 2.3642
# Epoch 49/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.5613 - mean_absolute_error: 2.3621
# Epoch 50/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.5569 - mean_absolute_error: 2.3592
# Epoch 51/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.5442 - mean_absolute_error: 2.3577
# Epoch 52/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.5160 - mean_absolute_error: 2.3557
# Epoch 53/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.5178 - mean_absolute_error: 2.3566
# Epoch 54/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.4931 - mean_absolute_error: 2.3518
# Epoch 55/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.4937 - mean_absolute_error: 2.3498
# Epoch 56/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 8.4856 - mean_absolute_error: 2.3498
# Epoch 57/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.4549 - mean_absolute_error: 2.3472
# Epoch 58/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.4403 - mean_absolute_error: 2.3448
# Epoch 59/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.4225 - mean_absolute_error: 2.3418
# Epoch 60/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.4192 - mean_absolute_error: 2.3411
# Epoch 61/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.4135 - mean_absolute_error: 2.3412
# Epoch 62/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.3930 - mean_absolute_error: 2.3383
# Epoch 63/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.4009 - mean_absolute_error: 2.3380
# Epoch 64/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.4053 - mean_absolute_error: 2.3381
# Epoch 65/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.3748 - mean_absolute_error: 2.3359
# Epoch 66/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.3818 - mean_absolute_error: 2.3355
# Epoch 67/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.3771 - mean_absolute_error: 2.3362
# Epoch 68/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.3662 - mean_absolute_error: 2.3337
# Epoch 69/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.3734 - mean_absolute_error: 2.3360
# Epoch 70/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.3501 - mean_absolute_error: 2.3322
# Epoch 71/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.3490 - mean_absolute_error: 2.3323
# Epoch 72/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 8.3407 - mean_absolute_error: 2.3315
# Epoch 73/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 8.3360 - mean_absolute_error: 2.3308
# Epoch 74/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.3158 - mean_absolute_error: 2.3282
# Epoch 75/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.3183 - mean_absolute_error: 2.3291
# Epoch 76/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.3257 - mean_absolute_error: 2.3290
# Epoch 77/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.3144 - mean_absolute_error: 2.3289
# Epoch 78/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.3029 - mean_absolute_error: 2.3277
# Epoch 79/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.3131 - mean_absolute_error: 2.3290
# Epoch 80/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.3067 - mean_absolute_error: 2.3281
# Epoch 81/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2989 - mean_absolute_error: 2.3268
# Epoch 82/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.3110 - mean_absolute_error: 2.3278
# Epoch 83/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.3047 - mean_absolute_error: 2.3273
# Epoch 84/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 8.3019 - mean_absolute_error: 2.3269
# Epoch 85/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2897 - mean_absolute_error: 2.3256
# Epoch 86/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2849 - mean_absolute_error: 2.3250
# Epoch 87/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.2919 - mean_absolute_error: 2.3244
# Epoch 88/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2924 - mean_absolute_error: 2.3250
# Epoch 89/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.2851 - mean_absolute_error: 2.3248
# Epoch 90/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.2893 - mean_absolute_error: 2.3249
# Epoch 91/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2855 - mean_absolute_error: 2.3244
# Epoch 92/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 8.2793 - mean_absolute_error: 2.3244
# Epoch 93/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2762 - mean_absolute_error: 2.3240
# Epoch 94/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.2789 - mean_absolute_error: 2.3246
# Epoch 95/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2754 - mean_absolute_error: 2.3239
# Epoch 96/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2741 - mean_absolute_error: 2.3238
# Epoch 97/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2614 - mean_absolute_error: 2.3216
# Epoch 98/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 8.2699 - mean_absolute_error: 2.3229
# Epoch 99/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2571 - mean_absolute_error: 2.3219
# Epoch 100/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 8.2640 - mean_absolute_error: 2.3227
# 2593/2593 - 3s - 1ms/step - loss: 10.9552 - mean_absolute_error: 2.6084
# Loss (MSE): 10.955230712890625
# Mean Absolute Error: 2.6084203720092773
# Root Mean Squared Error (RMSE): 3.3098686851430563
# emissions=0.00015159421486213322

# %%
y_temp_pred_probs = model.predict(X_temp_test, verbose=2)
# Out:
# 2593/2593 - 2s - 931us/step

# %%
y_temp_test_flat = y_temp_test.values.flatten()
y_temp_pred_flat = y_temp_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_temp_test_flat, y_temp_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_temp_real_x_pred_integrada.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2025-01-31 23:00:00"

df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_temp_test_flat, y_temp_pred_flat, timestamps_test, start_date, end_date, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_temp_over_time_integrada.png')

# %%
def model_predict_flat(X):
    return model.predict(X).flatten()

# %%
explainer = shap.KernelExplainer(model_predict_flat, X_temp_train[300000:300100])
shap_values = explainer.shap_values(X_temp_test[:100])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#   0%|          | 0/100 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 527us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 609us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 531us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 615us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 642us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 804us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 767us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 752us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6394/6394 ━━━━━━━━━━━━━━━━━━━━ 6s 894us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 785us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 738us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 808us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 764us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 927us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 850us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 869us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 976us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 882us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 832us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 809us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 880us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 792us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 988us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 919us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 759us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 879us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 919us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 772us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 878us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 820us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 806us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 776us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 937us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 818us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 837us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 963us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 927us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 902us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 974us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 795us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 858us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 920us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 801us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 895us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 876us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 759us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 874us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 773us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 972us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 876us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 956us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 837us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 789us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 873us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 860us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 974us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 855us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 790us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 878us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 854us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 928us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 884us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 2s 760us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 847us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 922us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 817us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 839us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 863us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 915us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 993us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 875us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 998us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 3194/3194 ━━━━━━━━━━━━━━━━━━━━ 3s 827us/step

# %%
shap.summary_plot(shap_values, X_temp_test[:100])

# %%
shap.summary_plot(shap_values, X_temp_test[:100], plot_type="bar", feature_names=X_temp.columns)

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_prec)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_prec)

# %%
X_prec_train, X_prec_test, y_prec_train, y_prec_test = split_train_test(X_prec, y_prec, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_prec.shape[1], activation='relu', input_shape=(X_prec.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp PRECIPITATION 100ep final",
    output_file='./codecarbon_emissions_mlp_temperatura_jac_mar_vm.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_prec_train, y_prec_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_prec_test, y_prec_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 849 (3.32 KB)
#  Trainable params: 849 (3.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 1.1594 - mean_absolute_error: 0.2348
# Epoch 2/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 1.1588 - mean_absolute_error: 0.2339
# Epoch 3/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step - loss: 1.1576 - mean_absolute_error: 0.2345
# Epoch 4/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step - loss: 1.1555 - mean_absolute_error: 0.2312
# Epoch 5/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step - loss: 1.1476 - mean_absolute_error: 0.2331
# Epoch 6/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step - loss: 1.1536 - mean_absolute_error: 0.2315
# Epoch 7/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step - loss: 1.1504 - mean_absolute_error: 0.2310
# Epoch 8/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 1.1303 - mean_absolute_error: 0.2244
# Epoch 9/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1.1447 - mean_absolute_error: 0.2303
# Epoch 10/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 1.1269 - mean_absolute_error: 0.2203
# Epoch 11/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.1259 - mean_absolute_error: 0.2241
# Epoch 12/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - loss: 1.1233 - mean_absolute_error: 0.2233
# Epoch 13/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - loss: 1.1191 - mean_absolute_error: 0.2222
# Epoch 14/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - loss: 1.1192 - mean_absolute_error: 0.2243
# Epoch 15/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 1.1175 - mean_absolute_error: 0.2247
# Epoch 16/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - loss: 1.1164 - mean_absolute_error: 0.2255
# Epoch 17/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - loss: 1.1185 - mean_absolute_error: 0.2248
# Epoch 18/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - loss: 1.1211 - mean_absolute_error: 0.2294
# Epoch 19/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - loss: 1.1214 - mean_absolute_error: 0.2267
# Epoch 20/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - loss: 1.1128 - mean_absolute_error: 0.2274
# Epoch 21/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - loss: 1.1259 - mean_absolute_error: 0.2337
# Epoch 22/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 26s 2ms/step - loss: 1.1142 - mean_absolute_error: 0.2268
# Epoch 23/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 26s 3ms/step - loss: 1.1109 - mean_absolute_error: 0.2289
# Epoch 24/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - loss: 1.1095 - mean_absolute_error: 0.2261
# Epoch 25/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 26s 3ms/step - loss: 1.1107 - mean_absolute_error: 0.2256
# Epoch 26/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1.1159 - mean_absolute_error: 0.2316
# Epoch 27/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.1112 - mean_absolute_error: 0.2289
# Epoch 28/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 1.1056 - mean_absolute_error: 0.2257
# Epoch 29/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 1.1044 - mean_absolute_error: 0.2266
# Epoch 30/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.1135 - mean_absolute_error: 0.2325
# Epoch 31/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.1070 - mean_absolute_error: 0.2279
# Epoch 32/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.1036 - mean_absolute_error: 0.2259
# Epoch 33/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.1115 - mean_absolute_error: 0.2289
# Epoch 34/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.1001 - mean_absolute_error: 0.2253
# Epoch 35/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.1016 - mean_absolute_error: 0.2242
# Epoch 36/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.1023 - mean_absolute_error: 0.2248
# Epoch 37/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 1.0998 - mean_absolute_error: 0.2253
# Epoch 38/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.0980 - mean_absolute_error: 0.2244
# Epoch 39/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 1.1130 - mean_absolute_error: 0.2356
# Epoch 40/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.0932 - mean_absolute_error: 0.2265
# Epoch 41/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.1015 - mean_absolute_error: 0.2278
# Epoch 42/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 1.0976 - mean_absolute_error: 0.2225
# Epoch 43/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 1.1010 - mean_absolute_error: 0.2296
# Epoch 44/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.0976 - mean_absolute_error: 0.2253
# Epoch 45/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0956 - mean_absolute_error: 0.2282
# Epoch 46/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0937 - mean_absolute_error: 0.2255
# Epoch 47/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1.0981 - mean_absolute_error: 0.2280
# Epoch 48/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.1034 - mean_absolute_error: 0.2302
# Epoch 49/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.0894 - mean_absolute_error: 0.2234
# Epoch 50/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.1045 - mean_absolute_error: 0.2347
# Epoch 51/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0863 - mean_absolute_error: 0.2248
# Epoch 52/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.1019 - mean_absolute_error: 0.2292
# Epoch 53/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 26s 2ms/step - loss: 1.1030 - mean_absolute_error: 0.2354
# Epoch 54/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1.0909 - mean_absolute_error: 0.2264
# Epoch 55/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0885 - mean_absolute_error: 0.2262
# Epoch 56/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 27s 3ms/step - loss: 1.0882 - mean_absolute_error: 0.2260
# Epoch 57/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 26s 3ms/step - loss: 1.0906 - mean_absolute_error: 0.2256
# Epoch 58/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 27s 3ms/step - loss: 1.0995 - mean_absolute_error: 0.2246
# Epoch 59/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0979 - mean_absolute_error: 0.2285
# Epoch 60/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 1.0923 - mean_absolute_error: 0.2282
# Epoch 61/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 1.0994 - mean_absolute_error: 0.2286
# Epoch 62/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - loss: 1.0911 - mean_absolute_error: 0.2268
# Epoch 63/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1.1087 - mean_absolute_error: 0.2359
# Epoch 64/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0863 - mean_absolute_error: 0.2295
# Epoch 65/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1.0944 - mean_absolute_error: 0.2312
# Epoch 66/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 1.0861 - mean_absolute_error: 0.2252
# Epoch 67/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1.0839 - mean_absolute_error: 0.2253
# Epoch 68/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0996 - mean_absolute_error: 0.2339
# Epoch 69/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 1.1133 - mean_absolute_error: 0.2419
# Epoch 70/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.0811 - mean_absolute_error: 0.2245
# Epoch 71/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.0820 - mean_absolute_error: 0.2264
# Epoch 72/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.0841 - mean_absolute_error: 0.2281
# Epoch 73/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0844 - mean_absolute_error: 0.2287
# Epoch 74/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 1.0971 - mean_absolute_error: 0.2312
# Epoch 75/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 1.0938 - mean_absolute_error: 0.2297
# Epoch 76/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 1.0803 - mean_absolute_error: 0.2242
# Epoch 77/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 1.0899 - mean_absolute_error: 0.2303
# Epoch 78/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0801 - mean_absolute_error: 0.2243
# Epoch 79/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.0922 - mean_absolute_error: 0.2274
# Epoch 80/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1.0829 - mean_absolute_error: 0.2251
# Epoch 81/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 27s 3ms/step - loss: 1.0893 - mean_absolute_error: 0.2253
# Epoch 82/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 1.0933 - mean_absolute_error: 0.2286
# Epoch 83/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.0970 - mean_absolute_error: 0.2286
# Epoch 84/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.0963 - mean_absolute_error: 0.2283
# Epoch 85/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.0909 - mean_absolute_error: 0.2270
# Epoch 86/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0939 - mean_absolute_error: 0.2314
# Epoch 87/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 1.0852 - mean_absolute_error: 0.2258
# Epoch 88/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 1.0967 - mean_absolute_error: 0.2274
# Epoch 89/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 1.0898 - mean_absolute_error: 0.2308
# Epoch 90/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.0765 - mean_absolute_error: 0.2255
# Epoch 91/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.0873 - mean_absolute_error: 0.2271
# Epoch 92/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 1.0921 - mean_absolute_error: 0.2323
# Epoch 93/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - loss: 1.0760 - mean_absolute_error: 0.2241
# Epoch 94/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - loss: 1.0833 - mean_absolute_error: 0.2275
# Epoch 95/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 44s 4ms/step - loss: 1.0763 - mean_absolute_error: 0.2241
# Epoch 96/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - loss: 1.0760 - mean_absolute_error: 0.2247
# Epoch 97/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 42s 4ms/step - loss: 1.0817 - mean_absolute_error: 0.2250
# Epoch 98/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - loss: 1.0802 - mean_absolute_error: 0.2239
# Epoch 99/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 34s 3ms/step - loss: 1.1045 - mean_absolute_error: 0.2304
# Epoch 100/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 28s 3ms/step - loss: 1.0904 - mean_absolute_error: 0.2297
# 2593/2593 - 4s - 2ms/step - loss: 46.3856 - mean_absolute_error: 0.4160
# Loss (MSE): 46.38557815551758
# Mean Absolute Error: 0.4160257577896118
# Root Mean Squared Error (RMSE): 6.810695864265088
# emissions=0.00018696175087339745

# %%
rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 6.810695864265088

# %%
y_prec_pred_probs = model.predict(X_prec_test, verbose=2)
# Out:
# 2593/2593 - 3s - 1ms/step

# %%
y_prec_test_flat = y_prec_test.values.flatten()
y_prec_pred_flat = y_prec_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_prec_test_flat, y_prec_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_prec_real_x_pred_integrada.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2024-01-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_prec_test_flat, y_prec_pred_flat, timestamps_test, start_date, end_date,  save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_prec_Integrada_2024-01.png')

# %%
explainer = shap.KernelExplainer(model_predict_flat, X_prec_train[:100])
shap_values = explainer.shap_values(X_prec_test[:100])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#   0%|          | 0/100 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 977us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 5s 726us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 926us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 989us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 884us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 954us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 940us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 978us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 949us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 6494/6494 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 988us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 943us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 958us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 6s 923us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 6500/6500 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step

# %%
shap.summary_plot(shap_values, X_prec_test[:100])

# %%
shap.summary_plot(shap_values, X_prec_test[:100], plot_type="bar", feature_names=X_prec.columns)

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_umid)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_umid)

# %%
X_umid_train, X_umid_test, y_umid_train, y_umid_test = split_train_test(X_umid, y_umid, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_umid.shape[1], activation='relu', input_shape=(X_umid.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp PRECIPITATION 100ep final",
    output_file='./codecarbon_emissions_mlp_temperatura_Maramaia.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_umid_train, y_umid_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_umid_test, y_umid_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 13)             │           182 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 663 (2.59 KB)
#  Trainable params: 663 (2.59 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 444.5543 - mean_absolute_error: 7.6408
# Epoch 2/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 96.0755 - mean_absolute_error: 4.4319
# Epoch 3/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 74.5673 - mean_absolute_error: 4.1506
# Epoch 4/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 70.4950 - mean_absolute_error: 3.9691
# Epoch 5/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 67.3807 - mean_absolute_error: 3.8739
# Epoch 6/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 63.4839 - mean_absolute_error: 3.7191
# Epoch 7/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 63.6917 - mean_absolute_error: 3.6933
# Epoch 8/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 61.8457 - mean_absolute_error: 3.6253
# Epoch 9/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 61.1492 - mean_absolute_error: 3.5717
# Epoch 10/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 59.8442 - mean_absolute_error: 3.5106
# Epoch 11/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - loss: 58.9493 - mean_absolute_error: 3.4689
# Epoch 12/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 58.5288 - mean_absolute_error: 3.4457
# Epoch 13/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 57.1977 - mean_absolute_error: 3.3761
# Epoch 14/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 56.6299 - mean_absolute_error: 3.3486
# Epoch 15/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 56.0187 - mean_absolute_error: 3.3360
# Epoch 16/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 56.1972 - mean_absolute_error: 3.3422
# Epoch 17/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - loss: 54.7448 - mean_absolute_error: 3.3107
# Epoch 18/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 28s 3ms/step - loss: 54.4776 - mean_absolute_error: 3.3179
# Epoch 19/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - loss: 53.8387 - mean_absolute_error: 3.3031
# Epoch 20/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - loss: 54.2278 - mean_absolute_error: 3.3084
# Epoch 21/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 28s 3ms/step - loss: 53.2846 - mean_absolute_error: 3.2367
# Epoch 22/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 28s 3ms/step - loss: 52.8798 - mean_absolute_error: 3.2216
# Epoch 23/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - loss: 52.9862 - mean_absolute_error: 3.2186
# Epoch 24/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - loss: 51.8682 - mean_absolute_error: 3.1763
# Epoch 25/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - loss: 51.7927 - mean_absolute_error: 3.1808
# Epoch 26/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - loss: 51.6712 - mean_absolute_error: 3.1770
# Epoch 27/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 51.0492 - mean_absolute_error: 3.1433
# Epoch 28/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - loss: 51.1699 - mean_absolute_error: 3.1331
# Epoch 29/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - loss: 51.2189 - mean_absolute_error: 3.1242
# Epoch 30/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - loss: 50.7077 - mean_absolute_error: 3.1197
# Epoch 31/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 35s 3ms/step - loss: 50.6595 - mean_absolute_error: 3.1154
# Epoch 32/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - loss: 50.0674 - mean_absolute_error: 3.1021
# Epoch 33/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - loss: 49.6974 - mean_absolute_error: 3.0749
# Epoch 34/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 41s 4ms/step - loss: 49.3374 - mean_absolute_error: 3.0543
# Epoch 35/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 40s 4ms/step - loss: 49.5602 - mean_absolute_error: 3.0649
# Epoch 36/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 56s 5ms/step - loss: 49.4402 - mean_absolute_error: 3.0660
# Epoch 37/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - loss: 49.3771 - mean_absolute_error: 3.0424
# Epoch 38/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 33s 3ms/step - loss: 49.3653 - mean_absolute_error: 3.0585
# Epoch 39/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - loss: 48.7368 - mean_absolute_error: 3.0192
# Epoch 40/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 37s 4ms/step - loss: 48.6711 - mean_absolute_error: 3.0317
# Epoch 41/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 32s 3ms/step - loss: 48.5032 - mean_absolute_error: 3.0096
# Epoch 42/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - loss: 48.4527 - mean_absolute_error: 3.0267
# Epoch 43/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 31s 3ms/step - loss: 50.3452 - mean_absolute_error: 3.0574
# Epoch 44/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 48.5807 - mean_absolute_error: 2.9978
# Epoch 45/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 47.5386 - mean_absolute_error: 2.9856
# Epoch 46/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 47.8236 - mean_absolute_error: 2.9789
# Epoch 47/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 47.2121 - mean_absolute_error: 2.9802
# Epoch 48/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 46.9200 - mean_absolute_error: 2.9818
# Epoch 49/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 47.1362 - mean_absolute_error: 2.9539
# Epoch 50/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 47.0226 - mean_absolute_error: 2.9554
# Epoch 51/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 46.7045 - mean_absolute_error: 2.9567
# Epoch 52/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 46.7175 - mean_absolute_error: 2.9364
# Epoch 53/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 46.6873 - mean_absolute_error: 2.9382
# Epoch 54/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 27s 3ms/step - loss: 46.2640 - mean_absolute_error: 2.9296
# Epoch 55/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 46.6941 - mean_absolute_error: 2.9189
# Epoch 56/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 44s 2ms/step - loss: 46.3972 - mean_absolute_error: 2.9339
# Epoch 57/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - loss: 46.6778 - mean_absolute_error: 2.9295
# Epoch 58/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 46.0314 - mean_absolute_error: 2.9194
# Epoch 59/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 46.8327 - mean_absolute_error: 2.9205
# Epoch 60/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - loss: 46.1360 - mean_absolute_error: 2.9175
# Epoch 61/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 46.0208 - mean_absolute_error: 2.9139
# Epoch 62/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 45.7286 - mean_absolute_error: 2.9064
# Epoch 63/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 45.8628 - mean_absolute_error: 2.8883
# Epoch 64/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 45.6998 - mean_absolute_error: 2.9023
# Epoch 65/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 45.5445 - mean_absolute_error: 2.8840
# Epoch 66/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 45.2395 - mean_absolute_error: 2.8734
# Epoch 67/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 45.3221 - mean_absolute_error: 2.8880
# Epoch 68/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 45.0918 - mean_absolute_error: 2.8695
# Epoch 69/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 45.4593 - mean_absolute_error: 2.8849
# Epoch 70/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 45.3317 - mean_absolute_error: 2.8823
# Epoch 71/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 44.9903 - mean_absolute_error: 2.8655
# Epoch 72/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 45.0144 - mean_absolute_error: 2.8515
# Epoch 73/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 44.8884 - mean_absolute_error: 2.8432
# Epoch 74/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 44.9427 - mean_absolute_error: 2.8611
# Epoch 75/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 44.8168 - mean_absolute_error: 2.8343
# Epoch 76/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 44.6689 - mean_absolute_error: 2.8355
# Epoch 77/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 44.7158 - mean_absolute_error: 2.8443
# Epoch 78/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 44.6964 - mean_absolute_error: 2.8183
# Epoch 79/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 44.3497 - mean_absolute_error: 2.7960
# Epoch 80/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 44.5966 - mean_absolute_error: 2.7679
# Epoch 81/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 44.1699 - mean_absolute_error: 2.7580
# Epoch 82/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 44.4811 - mean_absolute_error: 2.7548
# Epoch 83/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - loss: 44.1215 - mean_absolute_error: 2.7392
# Epoch 84/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 44.0355 - mean_absolute_error: 2.7316
# Epoch 85/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 44.2711 - mean_absolute_error: 2.7426
# Epoch 86/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 43.8154 - mean_absolute_error: 2.7133
# Epoch 87/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - loss: 44.5154 - mean_absolute_error: 2.7331
# Epoch 88/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 44.0679 - mean_absolute_error: 2.7392
# Epoch 89/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 44.4297 - mean_absolute_error: 2.7231
# Epoch 90/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 43.8399 - mean_absolute_error: 2.7230
# Epoch 91/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 43.6989 - mean_absolute_error: 2.7056
# Epoch 92/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 44.0182 - mean_absolute_error: 2.7196
# Epoch 93/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 43.9915 - mean_absolute_error: 2.6993
# Epoch 94/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 44.3566 - mean_absolute_error: 2.7040
# Epoch 95/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 37s 2ms/step - loss: 43.9824 - mean_absolute_error: 2.7192
# Epoch 96/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - loss: 43.7636 - mean_absolute_error: 2.7060
# Epoch 97/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 44.5427 - mean_absolute_error: 2.7101
# Epoch 98/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 43.1454 - mean_absolute_error: 2.6937
# Epoch 99/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - loss: 43.2353 - mean_absolute_error: 2.6845
# Epoch 100/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - loss: 43.1766 - mean_absolute_error: 2.6868
# 2593/2593 - 3s - 1ms/step - loss: 186.8125 - mean_absolute_error: 6.3046
# Loss (MSE): 186.81246948242188
# Mean Absolute Error: 6.304643154144287
# Root Mean Squared Error (RMSE): 13.667935816443604
# emissions=0.0002052884097184733

# %%
rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 13.667935816443604

# %%
y_umid_pred_probs = model.predict(X_umid_test, verbose=2)
# Out:
# 2593/2593 - 3s - 990us/step

# %%
y_umid_test_flat = y_umid_test.values.flatten()
y_umid_pred_flat = y_umid_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_umid_test_flat, y_umid_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_umid_real_x_pred_integrada.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2025-01-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_umid_test_flat, y_umid_pred_flat, timestamps_test, start_date, end_date,  save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_umid_real_x_pred_integrada_2024-2025.png')

# %%
explainer = shap.KernelExplainer(model_predict_flat, X_umid_train[:100])
shap_values = explainer.shap_values(X_umid_test[:100])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#   0%|          | 0/100 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 6s 923us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 6s 898us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 755us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 702us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 684us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 728us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 821us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 696us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 692us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 796us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 831us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 681us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 661us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 644us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 700us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 824us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 734us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 734us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 697us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 689us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 780us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 729us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 650us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 706us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 701us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 760us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 676us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 753us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 796us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 6s 973us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 664us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 707us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 669us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 3s 471us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 752us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 542us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 765us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 4s 681us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 6s 893us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 817us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 822us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 714us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 748us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 6s 879us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 755us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 702us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 823us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 710us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 770us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 706us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 781us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 6s 852us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 756us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 4s 670us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 4s 682us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 793us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 4s 669us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 710us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 697us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 733us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 741us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 748us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 708us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 725us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 692us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 760us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 759us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 703us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6475/6475 ━━━━━━━━━━━━━━━━━━━━ 5s 731us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 835us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 742us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 723us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 747us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 821us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 722us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 699us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 712us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 719us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 6s 860us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 711us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 757us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 764us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 769us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 714us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 721us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 707us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 720us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 721us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 705us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 714us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 780us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 814us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 725us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 756us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6482/6482 ━━━━━━━━━━━━━━━━━━━━ 5s 797us/step

# %%
shap.summary_plot(shap_values, X_umid_test[:100])

# %%
shap.summary_plot(shap_values, X_umid_test[:100], plot_type="bar", feature_names=X_umid.columns)
