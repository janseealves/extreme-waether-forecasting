# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
from sklearn.preprocessing import StandardScaler

from codecarbon import EmissionsTracker
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
df = pd.read_csv('Interpolado_Marambaia.csv', sep=',', encoding='utf8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191088 entries, 0 to 191087
# Data columns (total 18 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       191088 non-null  float64
#  1   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  191088 non-null  float64
#  2   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        191088 non-null  float64
#  3   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       191088 non-null  float64
#  4   RADIACAO GLOBAL (Kj/m²)                                191088 non-null  float64
#  5   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           191088 non-null  float64
#  6   TEMPERATURA DO PONTO DE ORVALHO (°C)                   191088 non-null  float64
#  7   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)             191088 non-null  float64
#  8   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)             191088 non-null  float64
#  9   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       191088 non-null  float64
#  10  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       191088 non-null  float64
#  11  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               191088 non-null  float64
#  12  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               191088 non-null  float64
#  13  UMIDADE RELATIVA DO AR, HORARIA (%)                    191088 non-null  float64
#  14  VENTO, DIREÇÃO HORARIA (gr) (° (gr))                   191088 non-null  float64
#  15  VENTO, RAJADA MAXIMA (m/s)                             191088 non-null  float64
#  16  VENTO, VELOCIDADE HORARIA (m/s)                        191088 non-null  float64
#  17  datetime                                               191088 non-null  object
# dtypes: float64(17), object(1)
# memory usage: 26.2+ MB

# %%
X_prec = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_prec = df[['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
X_temp = df[[
       'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_temp = df[['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)']]

# %%
X_umid = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_umid = df[['UMIDADE RELATIVA DO AR, HORARIA (%)']]

# %%
def split_train_test(X, y, train_size):
    X_train, X_test = X[:round(X.shape[0]*train_size)], X[round(X.shape[0]*train_size):]
    y_train, y_test = y[:round(y.shape[0]*train_size)], y[round(y.shape[0]*train_size):]

    return X_train, X_test, y_train, y_test

def plot_prediction_over_time(y_test, predictions, timestamps, start_date=None, end_date=None, save=False):
    timestamps = pd.to_datetime(timestamps)

    data = pd.DataFrame({
        'Timestamp': timestamps,
        'Actual': y_test,
        'Predicted': predictions
    })

    if start_date:
        data = data[data['Timestamp'] >= pd.to_datetime(start_date)]
    if end_date:
        data = data[data['Timestamp'] <= pd.to_datetime(end_date)]

    plt.figure(figsize=(12, 6))
    plt.plot(data['Timestamp'], data['Actual'], label='Actual Values', color='blue', linewidth=2)
    plt.plot(data['Timestamp'], data['Predicted'], label='Predicted Values', color='orange', linewidth=2)
    plt.xlabel('Time')
    plt.ylabel('Values')
    plt.title('Actual vs. Predicted Values Over Time')
    plt.legend()
    plt.grid(True)

    
    if save: 
        plt.savefig(save)
        
    plt.show()


def plot_real_vs_predicted(y_test, predictions, save=False):
    plt.figure(figsize=(8, 8))
    plt.scatter(y_test, predictions, alpha=0.7, color='blue')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--', color='red', linewidth=2, label="Ideal Fit")
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title("Real vs Predicted Values")
    plt.legend()
    plt.grid(True)

    if save: 
        plt.savefig(save)
    
    plt.show()

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_temp)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_temp)

# %%
X_temp_train, X_temp_test, y_temp_train, y_temp_test = split_train_test(X_temp, y_temp, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_temp.shape[1], activation='relu', input_shape=(X_temp.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp temperature train",
    output_file='./codecarbon_emissions_mlp_temperatura_Maramaia.csv',
    log_level = "critical"
)

tracker.start()


model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mean_absolute_error'] 
)

model.summary()

model.fit(X_temp_train, y_temp_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_temp_test, y_temp_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 549 (2.14 KB)
#  Trainable params: 549 (2.14 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 84.8457 - mean_absolute_error: 3.3987
# Epoch 2/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 11.3901 - mean_absolute_error: 2.6863
# Epoch 3/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 10.9270 - mean_absolute_error: 2.6347
# Epoch 4/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 10.2793 - mean_absolute_error: 2.5621
# Epoch 5/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 9.4563 - mean_absolute_error: 2.4754
# Epoch 6/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.8579 - mean_absolute_error: 2.4034
# Epoch 7/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 8.3903 - mean_absolute_error: 2.3372
# Epoch 8/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.3311 - mean_absolute_error: 2.3293
# Epoch 9/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.2307 - mean_absolute_error: 2.3152
# Epoch 10/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.1315 - mean_absolute_error: 2.3025
# Epoch 11/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.0796 - mean_absolute_error: 2.2965
# Epoch 12/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.0276 - mean_absolute_error: 2.2894
# Epoch 13/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.9827 - mean_absolute_error: 2.2829
# Epoch 14/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.9271 - mean_absolute_error: 2.2727
# Epoch 15/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.8902 - mean_absolute_error: 2.2662
# Epoch 16/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 7.8522 - mean_absolute_error: 2.2625
# Epoch 17/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.8305 - mean_absolute_error: 2.2585
# Epoch 18/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.7977 - mean_absolute_error: 2.2545
# Epoch 19/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.7801 - mean_absolute_error: 2.2518
# Epoch 20/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.7574 - mean_absolute_error: 2.2489
# Epoch 21/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.7431 - mean_absolute_error: 2.2464
# Epoch 22/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.7262 - mean_absolute_error: 2.2446
# Epoch 23/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.7471 - mean_absolute_error: 2.2456
# Epoch 24/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.7168 - mean_absolute_error: 2.2428
# Epoch 25/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.7097 - mean_absolute_error: 2.2412
# Epoch 26/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.6747 - mean_absolute_error: 2.2357
# Epoch 27/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.6568 - mean_absolute_error: 2.2356
# Epoch 28/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.6501 - mean_absolute_error: 2.2325
# Epoch 29/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.6447 - mean_absolute_error: 2.2320
# Epoch 30/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.6452 - mean_absolute_error: 2.2327
# Epoch 31/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.6198 - mean_absolute_error: 2.2285
# Epoch 32/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.6213 - mean_absolute_error: 2.2289
# Epoch 33/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.6091 - mean_absolute_error: 2.2274
# Epoch 34/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.6023 - mean_absolute_error: 2.2268
# Epoch 35/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5968 - mean_absolute_error: 2.2257
# Epoch 36/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5902 - mean_absolute_error: 2.2232
# Epoch 37/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 7.5965 - mean_absolute_error: 2.2260
# Epoch 38/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.5658 - mean_absolute_error: 2.2193
# Epoch 39/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.5818 - mean_absolute_error: 2.2215
# Epoch 40/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.5777 - mean_absolute_error: 2.2228
# Epoch 41/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.5666 - mean_absolute_error: 2.2198
# Epoch 42/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5619 - mean_absolute_error: 2.2198
# Epoch 43/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5541 - mean_absolute_error: 2.2171
# Epoch 44/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5554 - mean_absolute_error: 2.2174
# Epoch 45/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5477 - mean_absolute_error: 2.2166
# Epoch 46/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5300 - mean_absolute_error: 2.2150
# Epoch 47/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5482 - mean_absolute_error: 2.2169
# Epoch 48/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.5384 - mean_absolute_error: 2.2154
# Epoch 49/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5328 - mean_absolute_error: 2.2147
# Epoch 50/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5219 - mean_absolute_error: 2.2136
# Epoch 51/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5310 - mean_absolute_error: 2.2138
# Epoch 52/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5137 - mean_absolute_error: 2.2118
# Epoch 53/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5075 - mean_absolute_error: 2.2118
# Epoch 54/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5059 - mean_absolute_error: 2.2111
# Epoch 55/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4943 - mean_absolute_error: 2.2099
# Epoch 56/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5010 - mean_absolute_error: 2.2093
# Epoch 57/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.5002 - mean_absolute_error: 2.2093
# Epoch 58/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4764 - mean_absolute_error: 2.2065
# Epoch 59/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4814 - mean_absolute_error: 2.2078
# Epoch 60/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4921 - mean_absolute_error: 2.2086
# Epoch 61/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4784 - mean_absolute_error: 2.2068
# Epoch 62/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4647 - mean_absolute_error: 2.2050
# Epoch 63/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4886 - mean_absolute_error: 2.2074
# Epoch 64/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4900 - mean_absolute_error: 2.2081
# Epoch 65/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4747 - mean_absolute_error: 2.2061
# Epoch 66/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4724 - mean_absolute_error: 2.2062
# Epoch 67/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4614 - mean_absolute_error: 2.2042
# Epoch 68/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 7.4584 - mean_absolute_error: 2.2038
# Epoch 69/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4615 - mean_absolute_error: 2.2040
# Epoch 70/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4460 - mean_absolute_error: 2.2017
# Epoch 71/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4487 - mean_absolute_error: 2.2018
# Epoch 72/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4473 - mean_absolute_error: 2.2017
# Epoch 73/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4454 - mean_absolute_error: 2.2022
# Epoch 74/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4399 - mean_absolute_error: 2.2009
# Epoch 75/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4312 - mean_absolute_error: 2.1995
# Epoch 76/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4292 - mean_absolute_error: 2.1993
# Epoch 77/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4097 - mean_absolute_error: 2.1954
# Epoch 78/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4196 - mean_absolute_error: 2.1974
# Epoch 79/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4099 - mean_absolute_error: 2.1973
# Epoch 80/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4043 - mean_absolute_error: 2.1959
# Epoch 81/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.4065 - mean_absolute_error: 2.1976
# Epoch 82/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4009 - mean_absolute_error: 2.1956
# Epoch 83/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.3951 - mean_absolute_error: 2.1945
# Epoch 84/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4164 - mean_absolute_error: 2.1978
# Epoch 85/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3929 - mean_absolute_error: 2.1939
# Epoch 86/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.4072 - mean_absolute_error: 2.1963
# Epoch 87/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3897 - mean_absolute_error: 2.1933
# Epoch 88/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.3902 - mean_absolute_error: 2.1933
# Epoch 89/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.3733 - mean_absolute_error: 2.1908
# Epoch 90/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.3711 - mean_absolute_error: 2.1905
# Epoch 91/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3682 - mean_absolute_error: 2.1903
# Epoch 92/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3656 - mean_absolute_error: 2.1893
# Epoch 93/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3668 - mean_absolute_error: 2.1907
# Epoch 94/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3688 - mean_absolute_error: 2.1890
# Epoch 95/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3447 - mean_absolute_error: 2.1863
# Epoch 96/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3600 - mean_absolute_error: 2.1887
# Epoch 97/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 7.3454 - mean_absolute_error: 2.1870
# Epoch 98/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.3528 - mean_absolute_error: 2.1873
# Epoch 99/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.3416 - mean_absolute_error: 2.1863
# Epoch 100/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 7.3382 - mean_absolute_error: 2.1851
# 1195/1195 - 1s - 1ms/step - loss: 14.0486 - mean_absolute_error: 2.9453
# Loss (MSE): 14.04864501953125
# Mean Absolute Error: 2.9453117847442627
# Root Mean Squared Error (RMSE): 3.748152214029101
# emissions=6.831571704997151e-05

# %%
y_temp_pred_probs = model.predict(X_temp_test, verbose=2)
# Out:
# 1195/1195 - 1s - 582us/step

# %%
y_temp_test_flat = y_temp_test.values.flatten()
y_temp_pred_flat = y_temp_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_temp_test_flat, y_temp_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_temp_real_x_pred_Marambaia.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2025-01-31 23:00:00"

df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_temp_test_flat, y_temp_pred_flat, timestamps_test, start_date, end_date, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_temp_over_time.png')

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_prec)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_prec)

# %%
X_prec_train, X_prec_test, y_prec_train, y_prec_test = split_train_test(X_prec, y_prec, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_prec.shape[1], activation='relu', input_shape=(X_prec.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp PRECIPITATION 100ep final",
    output_file='./codecarbon_emissions_mlp_temperatura_Maramaia.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_prec_train, y_prec_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_prec_test, y_prec_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 849 (3.32 KB)
#  Trainable params: 849 (3.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 15.9559 - mean_absolute_error: 1.1910
# Epoch 2/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 1.5234 - mean_absolute_error: 0.6176
# Epoch 3/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.3501 - mean_absolute_error: 0.5396
# Epoch 4/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.2731 - mean_absolute_error: 0.4899
# Epoch 5/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.1768 - mean_absolute_error: 0.4175
# Epoch 6/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0713 - mean_absolute_error: 0.3342
# Epoch 7/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0329 - mean_absolute_error: 0.2716
# Epoch 8/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0262 - mean_absolute_error: 0.2509
# Epoch 9/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0070 - mean_absolute_error: 0.2396
# Epoch 10/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0201 - mean_absolute_error: 0.2415
# Epoch 11/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.0225 - mean_absolute_error: 0.2291
# Epoch 12/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0022 - mean_absolute_error: 0.2247
# Epoch 13/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9777 - mean_absolute_error: 0.2159
# Epoch 14/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9710 - mean_absolute_error: 0.2135
# Epoch 15/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.9758 - mean_absolute_error: 0.2182
# Epoch 16/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9749 - mean_absolute_error: 0.2126
# Epoch 17/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.0072 - mean_absolute_error: 0.2281
# Epoch 18/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9840 - mean_absolute_error: 0.2354
# Epoch 19/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 1.0237 - mean_absolute_error: 0.2455
# Epoch 20/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9990 - mean_absolute_error: 0.2459
# Epoch 21/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9948 - mean_absolute_error: 0.2312
# Epoch 22/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0035 - mean_absolute_error: 0.2474
# Epoch 23/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0091 - mean_absolute_error: 0.2517
# Epoch 24/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0103 - mean_absolute_error: 0.2522
# Epoch 25/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0148 - mean_absolute_error: 0.2520
# Epoch 26/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.9989 - mean_absolute_error: 0.2523
# Epoch 27/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0120 - mean_absolute_error: 0.2497
# Epoch 28/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.0077 - mean_absolute_error: 0.2395
# Epoch 29/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9923 - mean_absolute_error: 0.2424
# Epoch 30/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9748 - mean_absolute_error: 0.2298
# Epoch 31/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9728 - mean_absolute_error: 0.2226
# Epoch 32/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9730 - mean_absolute_error: 0.2242
# Epoch 33/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9693 - mean_absolute_error: 0.2184
# Epoch 34/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9573 - mean_absolute_error: 0.2147
# Epoch 35/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9546 - mean_absolute_error: 0.2038
# Epoch 36/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9595 - mean_absolute_error: 0.2106
# Epoch 37/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9466 - mean_absolute_error: 0.2082
# Epoch 38/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9549 - mean_absolute_error: 0.2091
# Epoch 39/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.9487 - mean_absolute_error: 0.2067
# Epoch 40/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9572 - mean_absolute_error: 0.2061
# Epoch 41/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9496 - mean_absolute_error: 0.2032
# Epoch 42/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9586 - mean_absolute_error: 0.2073
# Epoch 43/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9550 - mean_absolute_error: 0.2075
# Epoch 44/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9442 - mean_absolute_error: 0.2041
# Epoch 45/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9409 - mean_absolute_error: 0.2014
# Epoch 46/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9436 - mean_absolute_error: 0.2006
# Epoch 47/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9337 - mean_absolute_error: 0.1995
# Epoch 48/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.9425 - mean_absolute_error: 0.1986
# Epoch 49/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9433 - mean_absolute_error: 0.2043
# Epoch 50/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9455 - mean_absolute_error: 0.1997
# Epoch 51/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9405 - mean_absolute_error: 0.2007
# Epoch 52/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9384 - mean_absolute_error: 0.2003
# Epoch 53/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9314 - mean_absolute_error: 0.1992
# Epoch 54/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9322 - mean_absolute_error: 0.1971
# Epoch 55/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9350 - mean_absolute_error: 0.2030
# Epoch 56/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9363 - mean_absolute_error: 0.2027
# Epoch 57/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9293 - mean_absolute_error: 0.1965
# Epoch 58/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9430 - mean_absolute_error: 0.2000
# Epoch 59/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9430 - mean_absolute_error: 0.2021
# Epoch 60/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9480 - mean_absolute_error: 0.2091
# Epoch 61/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9333 - mean_absolute_error: 0.2019
# Epoch 62/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9280 - mean_absolute_error: 0.2009
# Epoch 63/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9308 - mean_absolute_error: 0.1982
# Epoch 64/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9236 - mean_absolute_error: 0.1962
# Epoch 65/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9289 - mean_absolute_error: 0.1978
# Epoch 66/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9403 - mean_absolute_error: 0.2060
# Epoch 67/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9289 - mean_absolute_error: 0.2028
# Epoch 68/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9268 - mean_absolute_error: 0.1998
# Epoch 69/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9355 - mean_absolute_error: 0.2040
# Epoch 70/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9316 - mean_absolute_error: 0.1999
# Epoch 71/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9212 - mean_absolute_error: 0.1952
# Epoch 72/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9282 - mean_absolute_error: 0.1978
# Epoch 73/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9299 - mean_absolute_error: 0.1999
# Epoch 74/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9251 - mean_absolute_error: 0.1982
# Epoch 75/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9196 - mean_absolute_error: 0.1935
# Epoch 76/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9238 - mean_absolute_error: 0.1943
# Epoch 77/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.9218 - mean_absolute_error: 0.1943
# Epoch 78/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.9224 - mean_absolute_error: 0.1936
# Epoch 79/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9260 - mean_absolute_error: 0.1949
# Epoch 80/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.9357 - mean_absolute_error: 0.2000
# Epoch 81/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9188 - mean_absolute_error: 0.1965
# Epoch 82/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9204 - mean_absolute_error: 0.1909
# Epoch 83/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9390 - mean_absolute_error: 0.2004
# Epoch 84/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9205 - mean_absolute_error: 0.1929
# Epoch 85/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9207 - mean_absolute_error: 0.1944
# Epoch 86/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9171 - mean_absolute_error: 0.1905
# Epoch 87/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9150 - mean_absolute_error: 0.1924
# Epoch 88/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9247 - mean_absolute_error: 0.1982
# Epoch 89/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9214 - mean_absolute_error: 0.1937
# Epoch 90/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9250 - mean_absolute_error: 0.1963
# Epoch 91/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9228 - mean_absolute_error: 0.1951
# Epoch 92/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9195 - mean_absolute_error: 0.1948
# Epoch 93/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9154 - mean_absolute_error: 0.1916
# Epoch 94/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.9235 - mean_absolute_error: 0.1945
# Epoch 95/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9273 - mean_absolute_error: 0.1968
# Epoch 96/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9190 - mean_absolute_error: 0.1953
# Epoch 97/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9170 - mean_absolute_error: 0.1928
# Epoch 98/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.9127 - mean_absolute_error: 0.1928
# Epoch 99/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9237 - mean_absolute_error: 0.1961
# Epoch 100/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.9140 - mean_absolute_error: 0.1947
# 1195/1195 - 1s - 1ms/step - loss: 1.5743 - mean_absolute_error: 0.3943
# Loss (MSE): 1.5743147134780884
# Mean Absolute Error: 0.39427483081817627
# Root Mean Squared Error (RMSE): 1.2547169854106894
# emissions=6.851166138365305e-05

# %%
rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 1.2547169854106894

# %%
y_prec_pred_probs = model.predict(X_prec_test, verbose=2)
# Out:
# 1195/1195 - 1s - 640us/step

# %%
y_prec_test_flat = y_prec_test.values.flatten()
y_prec_pred_flat = y_prec_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_prec_test_flat, y_prec_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_prec_real_x_pred_marambaia.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2024-01-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_prec_test_flat, y_prec_pred_flat, timestamps_test, start_date, end_date,  save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_prec_Marambaia_2024-01.png')

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_umid)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_umid)

# %%
X_umid_train, X_umid_test, y_umid_train, y_umid_test = split_train_test(X_umid, y_umid, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_umid.shape[1], activation='relu', input_shape=(X_umid.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\F8091795\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp PRECIPITATION 100ep final",
    output_file='./codecarbon_emissions_mlp_temperatura_Maramaia.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_umid_train, y_umid_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_umid_test, y_umid_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 13)             │           182 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 663 (2.59 KB)
#  Trainable params: 663 (2.59 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 165.8053 - mean_absolute_error: 8.6196
# Epoch 2/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - loss: 65.1106 - mean_absolute_error: 5.1272
# Epoch 3/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 62.1899 - mean_absolute_error: 4.9388
# Epoch 4/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 58.9589 - mean_absolute_error: 4.7614
# Epoch 5/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 55.2947 - mean_absolute_error: 4.6238
# Epoch 6/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 53.5553 - mean_absolute_error: 4.5829
# Epoch 7/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 50.8115 - mean_absolute_error: 4.4336
# Epoch 8/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 48.7751 - mean_absolute_error: 4.3359
# Epoch 9/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 46.7748 - mean_absolute_error: 4.2570
# Epoch 10/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 45.3414 - mean_absolute_error: 4.1971
# Epoch 11/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 44.4542 - mean_absolute_error: 4.1471
# Epoch 12/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 43.3294 - mean_absolute_error: 4.0874
# Epoch 13/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 42.0018 - mean_absolute_error: 3.9937
# Epoch 14/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 41.1064 - mean_absolute_error: 3.9414
# Epoch 15/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 39.8723 - mean_absolute_error: 3.8520
# Epoch 16/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 38.4238 - mean_absolute_error: 3.7291
# Epoch 17/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 37.4148 - mean_absolute_error: 3.6673
# Epoch 18/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 36.7173 - mean_absolute_error: 3.6356
# Epoch 19/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 36.0366 - mean_absolute_error: 3.5862
# Epoch 20/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 35.3188 - mean_absolute_error: 3.5671
# Epoch 21/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 33.7118 - mean_absolute_error: 3.4501
# Epoch 22/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 32.7866 - mean_absolute_error: 3.4092
# Epoch 23/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 31.5874 - mean_absolute_error: 3.3282
# Epoch 24/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 30.7614 - mean_absolute_error: 3.2667
# Epoch 25/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 30.2234 - mean_absolute_error: 3.2206
# Epoch 26/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 29.9065 - mean_absolute_error: 3.2118
# Epoch 27/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 29.1833 - mean_absolute_error: 3.1549
# Epoch 28/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 28.9937 - mean_absolute_error: 3.1307
# Epoch 29/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 28.7824 - mean_absolute_error: 3.1322
# Epoch 30/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 28.5923 - mean_absolute_error: 3.1098
# Epoch 31/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 28.3298 - mean_absolute_error: 3.1065
# Epoch 32/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 28.1714 - mean_absolute_error: 3.0897
# Epoch 33/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 27.8397 - mean_absolute_error: 3.0788
# Epoch 34/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 28.0748 - mean_absolute_error: 3.0655
# Epoch 35/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 27.4413 - mean_absolute_error: 3.0169
# Epoch 36/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 27.4703 - mean_absolute_error: 3.0421
# Epoch 37/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 27.1190 - mean_absolute_error: 2.9897
# Epoch 38/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 27.1030 - mean_absolute_error: 3.0069
# Epoch 39/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 26.7953 - mean_absolute_error: 2.9722
# Epoch 40/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 26.5710 - mean_absolute_error: 2.9615
# Epoch 41/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 27.6982 - mean_absolute_error: 3.0228
# Epoch 42/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 26.3266 - mean_absolute_error: 2.9491
# Epoch 43/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 25.9746 - mean_absolute_error: 2.9062
# Epoch 44/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 26.0998 - mean_absolute_error: 2.9180
# Epoch 45/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 25.8128 - mean_absolute_error: 2.9024
# Epoch 46/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 25.2826 - mean_absolute_error: 2.8473
# Epoch 47/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 25.9286 - mean_absolute_error: 2.8912
# Epoch 48/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 26.7600 - mean_absolute_error: 2.9151
# Epoch 49/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 26.0712 - mean_absolute_error: 2.8762
# Epoch 50/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 25.9350 - mean_absolute_error: 2.8689
# Epoch 51/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 25.5207 - mean_absolute_error: 2.8480
# Epoch 52/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 25.2046 - mean_absolute_error: 2.8234
# Epoch 53/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 25.1691 - mean_absolute_error: 2.8107
# Epoch 54/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 24.8269 - mean_absolute_error: 2.8051
# Epoch 55/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 24.7903 - mean_absolute_error: 2.7929
# Epoch 56/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 25.0165 - mean_absolute_error: 2.7802
# Epoch 57/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 24.4890 - mean_absolute_error: 2.7639
# Epoch 58/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 24.2524 - mean_absolute_error: 2.7496
# Epoch 59/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 24.4312 - mean_absolute_error: 2.7538
# Epoch 60/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 24.4078 - mean_absolute_error: 2.7395
# Epoch 61/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 23.8693 - mean_absolute_error: 2.6886
# Epoch 62/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 24.2256 - mean_absolute_error: 2.7227
# Epoch 63/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 23.9906 - mean_absolute_error: 2.7143
# Epoch 64/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 24.2205 - mean_absolute_error: 2.7250
# Epoch 65/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 24.0897 - mean_absolute_error: 2.7001
# Epoch 66/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 23.3125 - mean_absolute_error: 2.6527
# Epoch 67/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 24.0198 - mean_absolute_error: 2.6920
# Epoch 68/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 23.6758 - mean_absolute_error: 2.6932
# Epoch 69/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 23.3876 - mean_absolute_error: 2.6846
# Epoch 70/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 23.4317 - mean_absolute_error: 2.6766
# Epoch 71/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 22.8958 - mean_absolute_error: 2.6219
# Epoch 72/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 23.4816 - mean_absolute_error: 2.6805
# Epoch 73/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 22.5469 - mean_absolute_error: 2.5899
# Epoch 74/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 22.9449 - mean_absolute_error: 2.6325
# Epoch 75/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 23.0113 - mean_absolute_error: 2.6368
# Epoch 76/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 22.6516 - mean_absolute_error: 2.5959
# Epoch 77/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 22.6024 - mean_absolute_error: 2.6010
# Epoch 78/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 22.7960 - mean_absolute_error: 2.6151
# Epoch 79/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 22.2556 - mean_absolute_error: 2.5927
# Epoch 80/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 22.9468 - mean_absolute_error: 2.6421
# Epoch 81/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 22.7292 - mean_absolute_error: 2.6059
# Epoch 82/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.4506 - mean_absolute_error: 2.5727
# Epoch 83/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.4437 - mean_absolute_error: 2.5815
# Epoch 84/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 23.2092 - mean_absolute_error: 2.6257
# Epoch 85/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.4937 - mean_absolute_error: 2.5971
# Epoch 86/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.7162 - mean_absolute_error: 2.5861
# Epoch 87/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.5418 - mean_absolute_error: 2.5919
# Epoch 88/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 22.2677 - mean_absolute_error: 2.5688
# Epoch 89/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.6000 - mean_absolute_error: 2.5876
# Epoch 90/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.1748 - mean_absolute_error: 2.5637
# Epoch 91/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.2980 - mean_absolute_error: 2.5411
# Epoch 92/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.8659 - mean_absolute_error: 2.5849
# Epoch 93/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.1205 - mean_absolute_error: 2.5551
# Epoch 94/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 21.9751 - mean_absolute_error: 2.5373
# Epoch 95/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.1557 - mean_absolute_error: 2.5460
# Epoch 96/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.0046 - mean_absolute_error: 2.5483
# Epoch 97/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.1603 - mean_absolute_error: 2.5648
# Epoch 98/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 22.4109 - mean_absolute_error: 2.5705
# Epoch 99/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 22.3323 - mean_absolute_error: 2.5556
# Epoch 100/100
# 4778/4778 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 21.9371 - mean_absolute_error: 2.5222
# 1195/1195 - 2s - 2ms/step - loss: 237.6287 - mean_absolute_error: 9.4092
# Loss (MSE): 237.6287078857422
# Mean Absolute Error: 9.40921688079834
# Root Mean Squared Error (RMSE): 15.415210277052408
# emissions=6.888691095053883e-05

# %%
rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 15.415210277052408

# %%
y_umid_pred_probs = model.predict(X_umid_test, verbose=2)
# Out:
# 1195/1195 - 1s - 698us/step

# %%
y_umid_test_flat = y_umid_test.values.flatten()
y_umid_pred_flat = y_umid_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_umid_test_flat, y_umid_pred_flat, save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_umid_real_x_pred_marambaia.png')

# %%
start_date = "2024-01-01 01:00:00"
end_date = "2025-01-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_umid_test_flat, y_umid_pred_flat, timestamps_test, start_date, end_date,  save=r'C:\Users\F8091795\OneDrive - TIM\Pictures\mlp_umid_real_x_pred_marambaia_2024-2025.png')
